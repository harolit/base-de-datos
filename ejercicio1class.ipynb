# %% [markdown]
# <a href="https://colab.research.google.com/github/harolit/base-de-datos/blob/main/ejercicio1class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class persona:
  def __init__(self,nombre,edad):
    self.nombre=nombre
    self.edad=edad
  def saludo(self):
    print("hola, mi nombre es "+self.nombre)
p1=persona("harold",44)
p1.saludo()
# Out:
# hola, mi nombre es harold

# %%
class persona:
  def __init__(self,nombre,edad=18):
    self.nombre=nombre
    self.edad=edad
p1=persona("email")
p3=persona("jonathan",44)
p2=persona("tobias",25)
print(p1.nombre,p1.edad)
print(p2.nombre,p2.edad)
print(p3.nombre,p3.edad)
# Out:
# email 18
# tobias 25
# jonathan 44
