# %% [markdown]
# <a href="https://colab.research.google.com/github/harolit/base-de-datos/blob/main/entrega_actividad_tema_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#caso 1
class Libro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor  = autor
    def mostrar_info(self):
        print("Libro registrado:")
        print(f"Título : {self.titulo}")
        print(f"Autor : {self.autor}")
libro1 = Libro("Cien años de soledad", "Gabriel García Márquez")
libro1.mostrar_info()

#caso 2
class Libro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor  = autor
    def mostrar_info(self):
        print("Información del libro:")
        print(f"Título : {self.titulo}")
        print(f"Autor  : {self.autor}")
libro1 = Libro("El principito", "Antoine de Saint-Exupéry")
libro1.mostrar_info()
# Out:
# Libro registrado:
# Título : Cien años de soledad
# Autor : Gabriel García Márquez
# Información del libro:
# Título : El principito
# Autor  : Antoine de Saint-Exupéry

# %%
#caso 3
class Usuario:
    def __init__(self, nombre, identificacion):
        self.nombre = nombre
        self.identificacion = identificacion
    def mostrar_datos(self):
        print("Usuario registrado:")
        print(f"Nombre : {self.nombre}")
        print(f"Identificación : {self.identificacion}")
usuario1 = Usuario("María López", "CC-1001234567")
usuario1.mostrar_datos()

#caso 4
class Usuario:
    def __init__(self, nombre, identificacion):
        self.nombre = nombre
        self.identificacion = identificacion
    def mostrar_datos(self):
        print(f"Nombre: {self.nombre} | ID: {self.identificacion}")
usuario1 = Usuario("María López", "CC-1001234567")
usuario2 = Usuario("Carlos Pérez", "CC-9876543210")
usuario3 = Usuario("Ana Rodríguez", "CC-1122334455")
print("Usuarios registrados:")
usuario1.mostrar_datos()
usuario2.mostrar_datos()
usuario3.mostrar_datos()
# Out:
# Usuario registrado:
# Nombre : María López
# Identificación : CC-1001234567
# Usuarios registrados:
# Nombre: María López | ID: CC-1001234567
# Nombre: Carlos Pérez | ID: CC-9876543210
# Nombre: Ana Rodríguez | ID: CC-1122334455

# %%
#caso 5
class Libro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor = autor
    def __str__(self):
        return f"'{self.titulo}' — {self.autor}"
libro1 = Libro("Don Quijote de la Mancha", "Miguel de Cervantes")
libro2 = Libro("Rayuela", "Julio Cortázar")
print(libro1)
print(libro2)

#caso 6
class Libro:
    def __init__(self, titulo, autor, paginas):
        self.titulo = titulo
        self.autor = autor
        self.paginas = paginas
    def resumen(self):
        return (f"Libro : {self.titulo}\n"
                f"Autor : {self.autor}\n"
                f"Páginas: {self.paginas}")
    def es_largo(self):
        return self.paginas > 300
libro1 = Libro("1984", "George Orwell", 328)
print(libro1.resumen())
print(f"¿Es un libro largo? {libro1.es_largo()}")
# Out:
# 'Don Quijote de la Mancha' — Miguel de Cervantes
# 'Rayuela' — Julio Cortázar
# Libro : 1984
# Autor : George Orwell
# Páginas: 328
# ¿Es un libro largo? True

# %%
#caso 7
class Usuario:
    def __init__(self, nombre, identificacion):
        self.__nombre = nombre
        self.__identificacion = identificacion
    def get_nombre(self):
        return self.__nombre
    def get_identificacion(self):
        return self.__identificacion
    def mostrar_datos(self):
        print(f"Nombre: {self.__nombre} | ID: {self.__identificacion}")
usuario1 = Usuario("Laura Gómez", "CC-5050505050")
print("Nombre:", usuario1.get_nombre())
usuario1.mostrar_datos()

#caso 8
class Usuario:
    def __init__(self, nombre, identificacion):
        self.__nombre = nombre
        self.__identificacion = identificacion
    def get_nombre(self):
        return self.__nombre
    def set_nombre(self, nuevo_nombre):
        if nuevo_nombre and nuevo_nombre.strip():
            self.__nombre = nuevo_nombre.strip()
            print(f"Nombre actualizado a: {self.__nombre}")
        else:
            print("Error: el nombre no puede estar vacío.")
    def mostrar_datos(self):
        print(f"  Nombre: {self.__nombre} | ID: {self.__identificacion}")
usuario1 = Usuario("Pedro Ramírez", "CC-7070707070")
usuario1.mostrar_datos()
usuario1.set_nombre("Pedro A. Ramírez")
usuario1.mostrar_datos()
usuario1.set_nombre(" ")  # intento inválido
# Out:
# Nombre: Laura Gómez
# Nombre: Laura Gómez | ID: CC-5050505050
#   Nombre: Pedro Ramírez | ID: CC-7070707070
# Nombre actualizado a: Pedro A. Ramírez
#   Nombre: Pedro A. Ramírez | ID: CC-7070707070
# Error: el nombre no puede estar vacío.
